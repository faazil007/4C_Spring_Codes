# %% [markdown]
# # SMOTE

# %% [markdown]
# ## Importing required Libraries

# %%
import pandas as pd
from imblearn.over_sampling import SMOTE
from collections import Counter

# %% [markdown]
# ## Dataframe

# %%
X = pd.DataFrame({
    'X1':[1.5,2.5,7.0,7.5,8.5,9.0],
    'X2':[2.0,2.3,7.5,8.0,8.5,9.5] 
})
Y=[1,1,0,0,0,0]

# %%
print(" Before SMOTE", Counter(Y))
# Out:
#  Before SMOTE Counter({0: 4, 1: 2})

# %%
smote = SMOTE(random_state=42,k_neighbors=1)
x_resample,y_resample = smote.fit_resample(X,Y)
print("After SMOTE" , Counter(y_resample))
print(x_resample)
# Out:
# After SMOTE Counter({1: 4, 0: 4})
#          X1        X2
# 0  1.500000  2.000000
# 1  2.500000  2.300000
# 2  7.000000  7.500000
# 3  7.500000  8.000000
# 4  8.500000  8.500000
# 5  9.000000  9.500000
# 6  2.450714  2.285214
# 7  1.768006  2.080402
