# %% [markdown]
# # Working with Oversampler

# %% [markdown]
# ## Importing required Libraries

# %%
import pandas as pd
from imblearn.over_sampling import RandomOverSampler
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## Reading the CSV

# %%
data = pd.read_csv("../Datasets/Credit Card Defaulter Prediction.csv")
data.head()
# Out:
#    ID  LIMIT_BAL SEX   EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000   F  University  Married   24      2      2     -1     -1
# 1   2     120000   F  University   Single   26     -1      2      0      0
# 2   3      90000   F  University   Single   34      0      0      0      0
# 3   4      50000   F  University  Married   37      0      0      0      0
# 4   5      50000   M  University  Married   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# 0         0         0         0         Y
# ...

# %% [markdown]
# ## Encoding the Features

# %%
encoder = LabelEncoder()
for i in data.columns:
    data[i] = encoder.fit_transform(data[i])
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          0          2    0          4         1    3      4      4      1
# 1          1         12    0          4         3    5      1      4      2
# 2          2          9    0          4         3   13      2      2      2
# 3          3          5    0          4         1   16      2      2      2
# 4          4          5    1          4         1   36      1      2      1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29995         22    1          2         1   18      2      2      2
# 29996  29996         15    1          2         3   22      1      1      1
# 29997  29997          3    1          4         3   16      6      5      4
# 29998  29998          8    1          2         1   20      3      1      2
# 29999  29999          5    1          4         1   25      2      2      2
#
# ...

# %% [markdown]
# ## Splitting into X & Y

# %%
X = data.drop(columns='default ')
Y = data['default ']
oversampler = RandomOverSampler(random_state=42)
over_sampled_data_X, over_sampled_data_Y = oversampler.fit_resample(X,Y)

# %% [markdown]
# # Splitting into testing and training

# %%
x_train,x_test,y_train,y_test = train_test_split(over_sampled_data_X , over_sampled_data_Y,test_size=0.2)

# %% [markdown]
# ## Loading the model

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predictions

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# ## Checking Errors

# %%
MAE  = mean_absolute_error(y_test,y_pred)
print(f" Error is :: {MAE}")
# Out:
#  Error is :: 0.41926303778512075
