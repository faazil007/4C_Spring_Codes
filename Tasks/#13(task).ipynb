# %% [markdown]
# # Importing required Libraries

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# # Loading the dataset

# %%
iris= load_iris()
x= iris.data
y= iris.target

# %% [markdown]
# # Loading the model

# %%
model = LogisticRegression()

# %% [markdown]
# # Performing K-Fold Iterations

# %%
k=5
scores = cross_val_score(model, x,y,cv=k , scoring ='accuracy')
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # Calculate the mean and standard deviation

# %%
mean_accuracy = scores.mean()
std_accuracy = scores.std()
print(f" Mean Accuracy is :: {mean_accuracy}")
print(f" Standard Deviation of Accuracy is :: {std_accuracy}")
# Out:
#  Mean Accuracy is :: 0.9733333333333334
#  Standard Deviation of Accuracy is :: 0.02494438257849294
