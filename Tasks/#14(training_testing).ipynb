# %% [markdown]
# # Importing required Libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import numpy as np
import pandas as pd

# %% [markdown]
# # Evaluation

# %%
# Creating a simple DataFrame
data = pd.DataFrame([[1, 2, 3, 4],
                     [11, 22, 33, 2],
                     [21, 32, 42, 10]])

print("Original DataFrame:")
print(data)

# Separating features and target
x_data = data.iloc[:, :-1]
y_data = data.iloc[:, -1]

print("\nTarget (y_data):")
print(y_data)

print("\nFeatures (x_data):")
print(x_data)

# Splitting the data (corrected the duplicate variable name)
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.3, stratify=y_data)

print("\nTest data (x_test1):")
print(x_test1)

# Creating a second dataset
X = np.array([[1], [2], [3], [4], [5], [6], [7]])
Y = np.array([1, 2, 3, 4, 5, 6, 7])

# Splitting second dataset (again corrected duplicate variable name)
x_train2, x_test2, y_train2, y_test2 = train_test_split(X, Y, test_size=0.3, random_state=21)

# LogisticRegression is better suited for classification
# To avoid convergence warnings, we use 'max_iter=1000'
model = LogisticRegression(max_iter=1000)
model.fit(x_train2, y_train2)

# Predict on test data
test_predictions = model.predict(x_test2)

# Save predictions to a CSV file
df2 = pd.DataFrame(test_predictions)
print("\nShape of predictions DataFrame:")
print(df2.shape)

df2.to_csv("predicted.csv", index=False)

# Corrected print statement
print("\nType of test_predictions:")
print(type(test_predictions))
# Out:
# Original DataFrame:
#     0   1   2   3
# 0   1   2   3   4
# 1  11  22  33   2
# 2  21  32  42  10
#
# Target (y_data):
# 0     4
# 1     2
# 2    10
# Name: 3, dtype: int64
#
# Features (x_data):
#     0   1   2
# 0   1   2   3
# 1  11  22  33
# 2  21  32  42
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 20
#      17 print(x_data)
#      19 # Splitting the data (corrected the duplicate variable name)
# ---> 20 x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.3, stratify=y_data)
#      22 print("\nTest data (x_test1):")
#      23 print(x_test1)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
# ...
