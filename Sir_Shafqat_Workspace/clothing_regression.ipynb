# %% [markdown]
# # Importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
from sklearn.datasets import load_iris 
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.tree import  DecisionTreeRegressor 
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_digits
from sklearn.datasets import load_linnerud
from sklearn.metrics import mean_absolute_error
#from sklearn.datasets import load_diabetes
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Loading Dataset of Clothes

# %%
clothes= pd.read_csv("clothes_price_prediction_data.csv")
clothes.head()
# Out:
#           Brand Category  Color Size Material  Price
# 0   New Balance    Dress  White   XS    Nylon    182
# 1   New Balance    Jeans  Black   XS     Silk     57
# 2  Under Armour    Dress    Red    M     Wool    127
# 3          Nike    Shoes  Green    M   Cotton     77
# 4        Adidas  Sweater  White    M    Nylon    113

# %%
x=clothes.drop(columns=['Price'])
y=clothes["Price"]

# %% [markdown]
# # Encoding the Labels

# %%
encoder = LabelEncoder()
clothes["Brand"]= encoder.fit_transform(clothes["Brand"])
clothes["Category"]= encoder.fit_transform(clothes["Category"])
clothes["Color"]= encoder.fit_transform(clothes["Color"])
clothes["Size"]= encoder.fit_transform(clothes["Size"])
clothes["Material"]= encoder.fit_transform(clothes["Material"])

# %% [markdown]
# # Viewing Again

# %%
clothes.head()
# Out:
#    Brand  Category  Color  Size  Material  Price
# 0      1         0      4     4         2    182
# 1      1         2      0     4         4     57
# 2      5         0      3     1         5    127
# 3      2         3      2     1         0     77
# 4      0         4      4     1         2    113

# %% [markdown]
# # Splitting the data

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %% [markdown]
# # Loading the regressor

# %%
reg = DecisionTreeRegressor()
reg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8820\2074651708.py in ?()
#       1 reg = DecisionTreeRegressor()
# ----> 2 reg.fit(x_train,y_train)
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py in ?(self, X, y, sample_weight, check_input)
#    1395         self : DecisionTreeRegressor
#    1396             Fitted estimator.
#    1397         """
#    1398
# -> 1399         super()._fit(
#    1400             X,
# ...

# %% [markdown]
# # Predictions

# %%
y_pred = reg.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8820\895684175.py in ?()
# ----> 1 y_pred = regressor.predict(x_test)
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py in ?(self, X, check_input)
#     526         y : array-like of shape (n_samples,) or (n_samples, n_outputs)
#     527             The predicted classes, or the predict values.
#     528         """
#     529         check_is_fitted(self)
# --> 530         X = self._validate_X_predict(X, check_input)
#     531         proba = self.tree_.predict(X)
#     532         n_samples = X.shape[0]
#     533
#
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py in ?(self, X, check_input)
#     485             if self._support_missing_values(X):
#     486                 ensure_all_finite = "allow-nan"
# ...

# %% [markdown]
# # Mean Absolute Error

# %%
MSE = mean_absolute_error(y_pred,y_test)
print(MSE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 MSE = mean_absolute_error(y_pred,y_test)
#       2 print(MSE)
#
# NameError: name 'y_pred' is not defined
